# %% [markdown]
# # MATH 210 Introduction to Mathematical Computing
#
# **February 23, 2026**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Riemann Sum
#
# Compute right/left Riemann sums for
#
# $$
# \int_0^1 e^{-x} dx = 1 - \frac{1}{e}
# $$

# %%
x = np.linspace(0,1,50)
y = np.exp(-x)
plt.plot(x,y), plt.ylim([-0.25,1.25]), plt.grid(True)
plt.show()

# %% [markdown]
# Compute the right Riemann sum:

# %%
a = 0; b = 1; N = 100; dx = (b - a)/N;
x = np.linspace(a,b,N + 1)
xright = x[1:]
yright = np.exp(-xright)
R = np.sum(yright)*dx
print(R,1 - np.exp(-1))
# Out:
# 0.6289652236969588 0.6321205588285577

# %% [markdown]
# Compute left Riemann sum:

# %%
a = 0; b = 1; N = 100; dx = (b - a)/N;
x = np.linspace(a,b,N + 1)
xleft = x[:-1]
yleft = np.exp(-xleft)
L = np.sum(yleft)*dx
print(L,1 - np.exp(-1))
# Out:
# 0.6352864292852445 0.6321205588285577
