# %% [markdown]
# # MATH 210 Introduction to Mathematical Computing
#
# **March 18, 2026**

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as spi

# %%
k = 10; m = 1; L = 1;
def f(u,t):
    du0dt = u[1]
    du1dt = k/m*(L*u[0]/(u[0]**2 + u[2]**2)**0.5 - u[0])
    du2dt = u[3]
    du3dt = k/m*(L*u[2]/(u[0]**2 + u[2]**2)**0.5 - u[2])
    dudt = [du0dt,du1dt,du2dt,du3dt]
    return dudt

u0 = [0,-1,1,0]
t = np.linspace(0,2,201)
U = spi.odeint(f,u0,t)
plt.plot(U[:,0],U[:,2]), plt.axis([-2,2,-2,2])
plt.show()

# %%
U[0,:]
# Out:
# array([ 0., -1.,  1.,  0.])

# %%
U[1,:]
# Out:
# array([-9.99999996e-03, -9.99999986e-01,  9.99999995e-01, -1.65243197e-06])

# %%
U[-1,:]
# Out:
# array([-1.00307015, -0.00589471, -0.18396587, -0.99802032])
